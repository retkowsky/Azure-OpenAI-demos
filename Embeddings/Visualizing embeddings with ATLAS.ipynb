# %% [markdown]
# ## Visualizing Open AI Embeddings in Atlas

# %% [markdown]
# Atlas enables you to:
#
# - Store, update and organize multi-million point datasets of unstructured text, images and embeddings.
# - Visually interact with embeddings of your data from a web browser.
# - Operate over unstructured data and embeddings with topic modeling, semantic duplicate clustering and semantic search.
# - Generate high dimensional and two-dimensional embeddings of your data.
#
# Use Atlas to:
# - Visualize, interact, collaborate and share large datasets of text and embeddings.
# - Collaboratively curate your unstructured datasets (clean, tag and label)
# - Build high-availability apps powered by semantic search
# - Understand and debug the latent space of your AI model trains
# - Read about how Atlas works or get started below!
#
# https://docs.nomic.ai/index.html

# %%
#!pip install nomic

# %%
import datetime
import numpy as np
import nomic
import pandas as pd

from nomic import atlas

# %%
print(f"Today is {datetime.datetime.today().strftime('%d-%b-%Y %H:%M:%S')}")
# Out:
# Today is 09-Nov-2023 10:42:26

# %%
nomic.login('7xDPkYXSYDc1_ErdTPIcoAR9RNd8YDlkS3nVNXcVoIMZ6') # This is a public demo account

# %%
# !wget https://huggingface.co/spaces/ThirdEyeData/Semantic-Search/resolve/main/fine_food_reviews_with_embeddings_1k.csv
# Out:
# --2023-11-09 10:42:27--  https://huggingface.co/spaces/ThirdEyeData/Semantic-Search/resolve/main/fine_food_reviews_with_embeddings_1k.csv
# Resolving huggingface.co (huggingface.co)... 52.85.242.8, 52.85.242.35, 52.85.242.84, ...
# Connecting to huggingface.co (huggingface.co)|52.85.242.8|:443... connected.
# HTTP request sent, awaiting response... 302 Found
# Location: https://cdn-lfs.huggingface.co/repos/56/ee/56eec609e6e674d4ddc29404618b1577b6380cfddc0941873c0c018dd15096e1/0acc913f3deda7b91fcfb73e86a8780d490a54e33f2d2b9b6343078c45f0501b?response-content-disposition=attachment%3B+filename*%3DUTF-8%27%27fine_food_reviews_with_embeddings_1k.csv%3B+filename%3D%22fine_food_reviews_with_embeddings_1k.csv%22%3B&response-content-type=text%2Fcsv&Expires=1699785748&Policy=%7EcmVzcG9uc2UtY29udGVudC1kaXNwb3NpdGlvbj0qJnJlc3BvbnNlLWNvbnRlbnQtdHlwZT0qIn1dfQ__&Signature=lpPqXH7WAqUYfbO-8E9G0jqJhSxSUH7rER71Y4bdoLC6qmBjp7K7GrWRZvuGidhQuupuT1AbrtsO09TZIM3hK50y8o8Zt1-IUVZTKzJWxnaRsHc1XIQFdPBvTyA-%7Ek8eYzz8OmGW5wmb3dbIfpeuyZMK-RZv7LOmfJ9OZSYPFlCJRHeTycgL1IBi%7EcJxPTSjB9gmXDN3Wkta4FMHmIDvYkcwVLX40pkkSaRr92V3pOifgxtfI1HQu3IN-kI09YOdt2X5xzKxPau3kvMb15Su8q5USgolwCsRNeQ5sBSo3lh1fgnZPTO-lKVRG4gM-ysD6NTe5Htfp2D0WfWThyIMLQ__&Key-Pair-Id=KVTP0A1DKRTAX [following]
# --2023-11-09 10:42:28--  https://cdn-lfs.huggingface.co/repos/56/ee/56eec609e6e674d4ddc29404618b1577b6380cfddc0941873c0c018dd15096e1/0acc913f3deda7b91fcfb73e86a8780d490a54e33f2d2b9b6343078c45f0501b?response-content-disposition=attachment%3B+filename*%3DUTF-8%27%27fine_food_reviews_with_embeddings_1k.csv%3B+filename%3D%22fine_food_reviews_with_embeddings_1k.csv%22%3B&response-content-type=text%2Fcsv&Expires=1699785748&Policy=%7EcmVzcG9uc2UtY29udGVudC1kaXNwb3NpdGlvbj0qJnJlc3BvbnNlLWNvbnRlbnQtdHlwZT0qIn1dfQ__&Signature=lpPqXH7WAqUYfbO-8E9G0jqJhSxSUH7rER71Y4bdoLC6qmBjp7K7GrWRZvuGidhQuupuT1AbrtsO09TZIM3hK50y8o8Zt1-IUVZTKzJWxnaRsHc1XIQFdPBvTyA-%7Ek8eYzz8OmGW5wmb3dbIfpeuyZMK-RZv7LOmfJ9OZSYPFlCJRHeTycgL1IBi%7EcJxPTSjB9gmXDN3Wkta4FMHmIDvYkcwVLX40pkkSaRr92V3pOifgxtfI1HQu3IN-kI09YOdt2X5xzKxPau3kvMb15Su8q5USgolwCsRNeQ5sBSo3lh1fgnZPTO-lKVRG4gM-ysD6NTe5Htfp2D0WfWThyIMLQ__&Key-Pair-Id=KVTP0A1DKRTAX
# Resolving cdn-lfs.huggingface.co (cdn-lfs.huggingface.co)... 18.66.122.69, 18.66.122.62, 18.66.122.21, ...
# Connecting to cdn-lfs.huggingface.co (cdn-lfs.huggingface.co)|18.66.122.69|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 35254390 (34M) [text/csv]
# Saving to: ‘fine_food_reviews_with_embeddings_1k.csv.1’
#
# fine_food_reviews_w 100%[===================>]  33.62M  8.30MB/s    in 6.1s
#
# 2023-11-09 10:42:35 (5.51 MB/s) - ‘fine_food_reviews_with_embeddings_1k.csv.1’ saved [35254390/35254390]

# %%
csvfile = "fine_food_reviews_with_embeddings_1k.csv"

df = pd.read_csv(csvfile)
df
# Out:
#      Unnamed: 0   ProductId          UserId  Score
# 0             0  B003XPF9BO  A3R7JR3FMEBXQB      5  \
# 1           297  B003VXHGPK  A21VWSCGW7UUAR      4
# 2           296  B008JKTTUA  A34XBAIFT02B60      1
# 3           295  B000LKTTTW  A14MQ40CCU8B13      5
# 4           294  B001D09KAM  A34XBAIFT02B60      1
# ..          ...         ...             ...    ...
# 995         623  B0000CFXYA  A3GS4GWPIBV0NT      1
# 996         624  B0001BH5YM   A1BZ3HMAKK0NC      5
# 997         625  B0009ET7TC  A2FSDQY5AI6TNX      5
# 998         619  B007PA32L2  A15FF2P7RPKH6G      5
# 999         999  B001EQ5GEO  A3VYU0VO6DYV6I      5
#
#                                                Summary
# 0    where does one  start...and stop... with a tre...  \
# 1                     Good, but not Wolfgang Puck good
# 2    Should advertise coconut as an ingredient more...
# 3                                     Best tomato soup
# 4    Should advertise coconut as an ingredient more...
# ..                                                 ...
# 995                      Strange inflammation response
# 996                      My favorite and only  MUSTARD
# 997                           My furbabies LOVE these!
# 998                          got this for the daughter
# 999                                I love Maui Coffee!
#
#                                                   Text
# 0    Wanted to save some to bring to my Chicago fam...  \
# 1    Honestly, I have to admit that I expected a li...
# 2    First, these should be called Mac - Coconut ba...
# 3    I have a hard time finding packaged food of an...
# 4    First, these should be called Mac - Coconut ba...
# ..                                                 ...
# 995  Truthfully wasn't crazy about the taste of the...
# 996  You've just got to experience this mustard... ...
# 997  Shake the container and they come running. Eve...
# 998  all i have heard since she got a kuerig is why...
# 999  My first experience with Maui Coffee was bring...
#
#                                               combined  n_tokens
# 0    Title: where does one  start...and stop... wit...        52  \
# 1    Title: Good, but not Wolfgang Puck good; Conte...       178
# 2    Title: Should advertise coconut as an ingredie...        78
# 3    Title: Best tomato soup; Content: I have a har...       111
# 4    Title: Should advertise coconut as an ingredie...        78
# ..                                                 ...       ...
# 995  Title: Strange inflammation response; Content:...       110
# 996  Title: My favorite and only  MUSTARD; Content:...        80
# 997  Title: My furbabies LOVE these!; Content: Shak...        47
# 998  Title: got this for the daughter; Content: all...        50
# 999  Title: I love Maui Coffee!; Content: My first ...       118
#
#                                              embedding
# 0    [0.007018072064965963, -0.02731654793024063, 0...
# 1    [-0.003140551969408989, -0.009995664469897747,...
# 2    [-0.01757248118519783, -8.266511576948687e-05,...
# 3    [-0.0013932279543951154, -0.011112828738987446...
# 4    [-0.01757248118519783, -8.266511576948687e-05,...
# ..                                                 ...
# 995  [0.00011091353371739388, -0.00466986745595932,...
# 996  [-0.020869314670562744, -0.013138455338776112,...
# 997  [-0.009749102406203747, -0.0068712360225617886...
# 998  [-0.00521062919870019, 0.0009606690146028996, ...
# 999  [-0.006057822611182928, -0.015015840530395508,...
#
# [1000 rows x 9 columns]

# %%
df
# Out:
#      Unnamed: 0   ProductId          UserId  Score
# 0             0  B003XPF9BO  A3R7JR3FMEBXQB      5  \
# 1           297  B003VXHGPK  A21VWSCGW7UUAR      4
# 2           296  B008JKTTUA  A34XBAIFT02B60      1
# 3           295  B000LKTTTW  A14MQ40CCU8B13      5
# 4           294  B001D09KAM  A34XBAIFT02B60      1
# ..          ...         ...             ...    ...
# 995         623  B0000CFXYA  A3GS4GWPIBV0NT      1
# 996         624  B0001BH5YM   A1BZ3HMAKK0NC      5
# 997         625  B0009ET7TC  A2FSDQY5AI6TNX      5
# 998         619  B007PA32L2  A15FF2P7RPKH6G      5
# 999         999  B001EQ5GEO  A3VYU0VO6DYV6I      5
#
#                                                Summary
# 0    where does one  start...and stop... with a tre...  \
# 1                     Good, but not Wolfgang Puck good
# 2    Should advertise coconut as an ingredient more...
# 3                                     Best tomato soup
# 4    Should advertise coconut as an ingredient more...
# ..                                                 ...
# 995                      Strange inflammation response
# 996                      My favorite and only  MUSTARD
# 997                           My furbabies LOVE these!
# 998                          got this for the daughter
# 999                                I love Maui Coffee!
#
#                                                   Text
# 0    Wanted to save some to bring to my Chicago fam...  \
# 1    Honestly, I have to admit that I expected a li...
# 2    First, these should be called Mac - Coconut ba...
# 3    I have a hard time finding packaged food of an...
# 4    First, these should be called Mac - Coconut ba...
# ..                                                 ...
# 995  Truthfully wasn't crazy about the taste of the...
# 996  You've just got to experience this mustard... ...
# 997  Shake the container and they come running. Eve...
# 998  all i have heard since she got a kuerig is why...
# 999  My first experience with Maui Coffee was bring...
#
#                                               combined  n_tokens
# 0    Title: where does one  start...and stop... wit...        52  \
# 1    Title: Good, but not Wolfgang Puck good; Conte...       178
# 2    Title: Should advertise coconut as an ingredie...        78
# 3    Title: Best tomato soup; Content: I have a har...       111
# 4    Title: Should advertise coconut as an ingredie...        78
# ..                                                 ...       ...
# 995  Title: Strange inflammation response; Content:...       110
# 996  Title: My favorite and only  MUSTARD; Content:...        80
# 997  Title: My furbabies LOVE these!; Content: Shak...        47
# 998  Title: got this for the daughter; Content: all...        50
# 999  Title: I love Maui Coffee!; Content: My first ...       118
#
#                                              embedding
# 0    [0.007018072064965963, -0.02731654793024063, 0...
# 1    [-0.003140551969408989, -0.009995664469897747,...
# 2    [-0.01757248118519783, -8.266511576948687e-05,...
# 3    [-0.0013932279543951154, -0.011112828738987446...
# 4    [-0.01757248118519783, -8.266511576948687e-05,...
# ..                                                 ...
# 995  [0.00011091353371739388, -0.00466986745595932,...
# 996  [-0.020869314670562744, -0.013138455338776112,...
# 997  [-0.009749102406203747, -0.0068712360225617886...
# 998  [-0.00521062919870019, 0.0009606690146028996, ...
# 999  [-0.006057822611182928, -0.015015840530395508,...
#
# [1000 rows x 9 columns]

# %%
embeddings = np.array(df.embedding.apply(eval).to_list())
embeddings
# Out:
# array([[ 7.01807206e-03, -2.73165479e-02,  1.05734831e-02, ...,
#         -7.01120170e-03, -2.18614824e-02, -3.75671238e-02],
#        [-3.14055197e-03, -9.99566447e-03, -3.48033849e-03, ...,
#         -9.74494778e-03, -2.39829952e-03, -9.20392852e-03],
#        [-1.75724812e-02, -8.26651158e-05, -1.15222773e-02, ...,
#         -1.39020244e-02, -3.90170924e-02, -2.35151257e-02],
#        ...,
#        [-9.74910241e-03, -6.87123602e-03, -5.70622832e-03, ...,
#         -3.00459806e-02, -8.14515445e-03, -1.95114054e-02],
#        [-5.21062920e-03,  9.60669015e-04,  2.82862745e-02, ...,
#         -5.38039953e-03, -1.33138765e-02, -2.71892995e-02],
#        [-6.05782261e-03, -1.50158405e-02, -2.07575737e-03, ...,
#         -2.90671214e-02, -1.41164539e-02, -2.28756946e-02]])

# %%
df = df.drop('embedding', axis=1)
df = df.rename(columns={'Unnamed: 0': 'id'})
df['id'] = df['id'].astype(str)

df.head()
# Out:
#     id   ProductId          UserId  Score
# 0    0  B003XPF9BO  A3R7JR3FMEBXQB      5  \
# 1  297  B003VXHGPK  A21VWSCGW7UUAR      4
# 2  296  B008JKTTUA  A34XBAIFT02B60      1
# 3  295  B000LKTTTW  A14MQ40CCU8B13      5
# 4  294  B001D09KAM  A34XBAIFT02B60      1
#
#                                              Summary
# 0  where does one  start...and stop... with a tre...  \
# 1                   Good, but not Wolfgang Puck good
# 2  Should advertise coconut as an ingredient more...
# 3                                   Best tomato soup
# 4  Should advertise coconut as an ingredient more...
#
#                                                 Text
# 0  Wanted to save some to bring to my Chicago fam...  \
# 1  Honestly, I have to admit that I expected a li...
# 2  First, these should be called Mac - Coconut ba...
# 3  I have a hard time finding packaged food of an...
# 4  First, these should be called Mac - Coconut ba...
#
#                                             combined  n_tokens
# 0  Title: where does one  start...and stop... wit...        52
# 1  Title: Good, but not Wolfgang Puck good; Conte...       178
# 2  Title: Should advertise coconut as an ingredie...        78
# 3  Title: Best tomato soup; Content: I have a har...       111
# 4  Title: Should advertise coconut as an ingredie...        78

# %%
df.shape
# Out:
# (1000, 8)

# %%
project = atlas.map_embeddings(embeddings=embeddings,
                               data=df.to_dict('records'),
                               id_field='id',
                               colorable_fields=['Score'])
map = project.maps[0]
# Out:
# 2023-11-09 10:42:43.197 | INFO     | nomic.project:_create_project:790 - Creating project `obsolete-occasion` in organization `Atlas Demo`
# 2023-11-09 10:42:49.226 | INFO     | nomic.atlas:map_embeddings:107 - Uploading embeddings to Atlas.
# 1it [00:11, 11.88s/it]
# 2023-11-09 10:43:01.607 | INFO     | nomic.project:_add_data:1422 - Upload succeeded.
# 2023-11-09 10:43:01.608 | INFO     | nomic.atlas:map_embeddings:126 - Embedding upload succeeded.
# 2023-11-09 10:43:03.141 | INFO     | nomic.project:create_index:1132 - Created map `obsolete-occasion` in project `obsolete-occasion`: https://atlas.nomic.ai/map/47c5d6b0-ed07-4708-9a36-c8b214a61b76/3662a65f-ff10-4096-9e08-0438505464e8
# 2023-11-09 10:43:03.142 | INFO     | nomic.atlas:map_embeddings:139 - obsolete-occasion: https://atlas.nomic.ai/map/47c5d6b0-ed07-4708-9a36-c8b214a61b76/3662a65f-ff10-4096-9e08-0438505464e8

# %%
map
# Out:
# obsolete-occasion: https://atlas.nomic.ai/map/47c5d6b0-ed07-4708-9a36-c8b214a61b76/3662a65f-ff10-4096-9e08-0438505464e8

# %% [markdown]
# <img src="capture.png">
