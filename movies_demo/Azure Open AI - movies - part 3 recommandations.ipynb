# %% [markdown]
# # Movies recommendation with Azure Open AI & Azure Cognitive Search
# ## Part 3 - Recommandations

# %% [markdown]
# <img src="https://github.com/retkowsky/images/blob/master/movies_search.png?raw=true">

# %%
# %pip install azure-search-documents --pre --upgrade

# %%
# %pip install youtube-search-python

# %%
import json
import movieposters as mp
import openai
import os
import pytz
import requests
import sys
import time

from azure.core.credentials import AzureKeyCredential
from azure.search.documents import SearchClient
from azure.search.documents.indexes import SearchIndexClient
from azure.search.documents.models import Vector

from datetime import datetime
from dotenv import load_dotenv
from IPython.display import IFrame, display
from io import BytesIO
from PIL import Image
from youtubesearchpython import VideosSearch, Comments

# %%
sys.version
# Out:
# '3.10.10 (main, Mar 21 2023, 18:45:11) [GCC 11.2.0]'

# %%
local_tz = pytz.timezone(requests.get("https://ipinfo.io").json()["timezone"])
print("Local time:", datetime.now(local_tz).strftime("%d-%b-%Y %H:%M:%S"))
# Out:
# Local time: 04-Sep-2023 13:08:02

# %%
print("Open AI version:", openai.__version__)
# Out:
# Open AI version: 0.27.9

# %%
load_dotenv("azure.env")

openai.api_type: str = "azure"
openai.api_key = os.getenv("OPENAI_API_KEY")
openai.api_base = os.getenv("OPENAI_API_BASE")
openai.api_version = os.getenv("OPENAI_API_VERSION")

acs_endpoint = os.getenv("AZURE_SEARCH_SERVICE_ENDPOINT")
acs_key = os.getenv("AZURE_SEARCH_ADMIN_KEY")

# %%
# Azure Open AI embeddings model to use
embeddings_engine = "text-embedding-ada-002"

# %% [markdown]
# - Vector search is in public preview
# - Model name: text-embedding-ada-002
# - Model version: 2
# - API version: 2023-05-15

# %%
# Azure Cognitive Search index name to create
index_name = "moviereview"

# %% [markdown]
# ## 1. Functions

# %%
def acs_delete_index(index_name):
    """
    Deleting an Azure Cognitive Search index
    Input: index name (string)
    """
    start = time.time()
    search_client = SearchIndexClient(
        endpoint=acs_endpoint, credential=AzureKeyCredential(acs_key)
    )

    try:
        print("Deleting the Azure Cognitive Search index:", index_name)
        search_client.delete_index(index_name)
        print("Done. Elapsed time:", round(time.time() - start, 2), "secs")
    except:
        print("Cannot delete index. Check the index name.")

# %%
def acs_index_stats(index_name):
    """
    Get statistics about Azure Cognitive Search index
    Input: index name (string)
    """
    url = (
        acs_endpoint
        + "/indexes/"
        + index_name
        + "/stats?api-version=2021-04-30-Preview"
    )
    headers = {
        "Content-Type": "application/json",
        "api-key": acs_key,
    }
    response = requests.get(url, headers=headers)
    print("Azure Cognitive Search index status for:", index_name, "\n")

    if response.status_code == 200:
        res = response.json()
        print(json.dumps(res, indent=2))
        document_count = res["documentCount"]
        storage_size = res["storageSize"]

    else:
        print("Request failed with status code:", response.status_code)

    return document_count, storage_size

# %%
def acs_index_status(index_name):
    """
    Azure Cognitive Search index status
    Input: index name (string)
    """
    print("Azure Cognitive Search Index:", index_name, "\n")

    headers = {"Content-Type": "application/json", "api-key": acs_key}
    params = {"api-version": "2021-04-30-Preview"}
    index_status = requests.get(
        acs_endpoint + "/indexes/" + index_name, headers=headers, params=params
    )

    try:
        print(json.dumps((index_status.json()), indent=5))
    except:
        print("Request failed with status code:", response.status_code)

# %%
def azure_openai_text_embeddings(text):
    """
    Generating embeddings from text using Azure Open AI
    Input: text
    Output: vector embedding
    """
    embeddings = openai.Embedding.create(
        input=text,
        deployment_id=embeddings_engine,
    )
    embeddings = embeddings["data"][0]["embedding"]

    return embeddings

# %%
def get_list(movielist):
    """
    Get list of movies
    Input: movies list (list)
    Output: results (text)
    """
    pattern = r"\d+\.\s(.+)"
    matches = re.findall(pattern, movielist)
    for idx, movie in enumerate(matches, start=1):
        print(f"Movie {idx}: {movie}.")

    return matches

# %% [markdown]
# ## 2. Azure Cognitive Search index

# %% [markdown]
# ### Azure Cognitive Search vector store
# <img src="https://github.com/retkowsky/images/blob/master/vector_search_architecture.png?raw=true">

# %%
acs_index_status(index_name)
# Out:
# Azure Cognitive Search Index: moviereview
#
# {
#      "@odata.context": "https://azurecogsearcheastussr.search.windows.net/$metadata#indexes/$entity",
#      "@odata.etag": "\"0x8DBAA0BED295DB4\"",
#      "name": "moviereview",
#      "defaultScoringProfile": null,
#      "fields": [
#           {
#                "name": "imdb_id",
#                "type": "Edm.String",
#                "searchable": false,
#                "filterable": true,
#                "retrievable": true,
#                "sortable": true,
#                "facetable": true,
#                "key": true,
#                "indexAnalyzer": null,
#                "searchAnalyzer": null,
#                "analyzer": null,
#                "normalizer": null,
#                "synonymMaps": []
#           },
#           {
#                "name": "title",
#                "type": "Edm.String",
#                "searchable": true,
#                "filterable": true,
#                "retrievable": true,
#                "sortable": false,
#                "facetable": false,
#                "key": false,
#                "indexAnalyzer": null,
#                "searchAnalyzer": null,
#                "analyzer": null,
#                "normalizer": null,
#                "synonymMaps": []
#           },
#           {
#                "name": "cast",
#                "type": "Edm.String",
#                "searchable": true,
#                "filterable": true,
#                "retrievable": true,
#                "sortable": false,
#                "facetable": false,
#                "key": false,
#                "indexAnalyzer": null,
#                "searchAnalyzer": null,
#                "analyzer": null,
#                "normalizer": null,
#                "synonymMaps": []
#           },
#           {
#                "name": "director",
#                "type": "Edm.String",
#                "searchable": true,
#                "filterable": true,
#                "retrievable": true,
#                "sortable": false,
#                "facetable": false,
#                "key": false,
#                "indexAnalyzer": null,
#                "searchAnalyzer": null,
#                "analyzer": null,
#                "normalizer": null,
#                "synonymMaps": []
#           },
#           {
#                "name": "description",
#                "type": "Edm.String",
#                "searchable": true,
#                "filterable": false,
#                "retrievable": true,
#                "sortable": false,
#                "facetable": false,
#                "key": false,
#                "indexAnalyzer": null,
#                "searchAnalyzer": null,
#                "analyzer": null,
#                "normalizer": null,
#                "synonymMaps": []
#           },
#           {
#                "name": "genres",
#                "type": "Edm.String",
#                "searchable": true,
#                "filterable": true,
#                "retrievable": true,
#                "sortable": false,
#                "facetable": false,
#                "key": false,
#                "indexAnalyzer": null,
#                "searchAnalyzer": null,
#                "analyzer": null,
#                "normalizer": null,
#                "synonymMaps": []
#           },
#           {
#                "name": "year",
#                "type": "Edm.String",
#                "searchable": true,
#                "filterable": true,
#                "retrievable": true,
#                "sortable": false,
#                "facetable": false,
#                "key": false,
#                "indexAnalyzer": null,
#                "searchAnalyzer": null,
#                "analyzer": null,
#                "normalizer": null,
#                "synonymMaps": []
#           },
#           {
#                "name": "embed_overview",
#                "type": "Collection(Edm.Single)",
#                "searchable": true,
#                "filterable": false,
#                "retrievable": true,
#                "sortable": false,
#                "facetable": false,
#                "key": false,
#                "indexAnalyzer": null,
#                "searchAnalyzer": null,
#                "analyzer": null,
#                "normalizer": null,
#                "synonymMaps": []
#           },
#           {
#                "name": "embed_title",
#                "type": "Collection(Edm.Single)",
#                "searchable": true,
#                "filterable": false,
#                "retrievable": true,
#                "sortable": false,
#                "facetable": false,
#                "key": false,
#                "indexAnalyzer": null,
#                "searchAnalyzer": null,
#                "analyzer": null,
#                "normalizer": null,
#                "synonymMaps": []
#           }
#      ],
#      "scoringProfiles": [],
#      "corsOptions": null,
#      "suggesters": [],
#      "analyzers": [],
#      "normalizers": [],
#      "tokenizers": [],
#      "tokenFilters": [],
#      "charFilters": [],
#      "encryptionKey": null,
#      "similarity": {
#           "@odata.type": "#Microsoft.Azure.Search.BM25Similarity",
#           "k1": null,
#           "b": null
#      },
#      "semantic": {
#           "defaultConfiguration": null,
#           "configurations": [
#                {
#                     "name": "my-semantic-config",
#                     "prioritizedFields": {
#                          "titleField": {
#                               "fieldName": "title"
#                          },
#                          "prioritizedContentFields": [
#                               {
#                                    "fieldName": "description"
#                               }
#                          ],
#                          "prioritizedKeywordsFields": [
#                               {
#                                    "fieldName": "genres"
#                               }
#                          ]
#                     }
#                }
#           ]
#      }
# }

# %%
document_count, storage_size = acs_index_stats(index_name)
# Out:
# Azure Cognitive Search index status for: moviereview
#
# {
#   "@odata.context": "https://azurecogsearcheastussr.search.windows.net/$metadata#Microsoft.Azure.Search.V2021_04_30_Preview.IndexStatistics",
#   "documentCount": 10784,
#   "storageSize": 564466206
# }

# %%
print("Number of documents in the index =", f"{document_count:,}")
print("Size of the index =", round(storage_size / (1024 * 1024), 2), "MB")
# Out:
# Number of documents in the index = 10,784
# Size of the index = 538.32 MB

# %% [markdown]
# ## 3. Functions

# %%
def azure_chatgpt_movies(prompt, max_retries=3, retry_delay=1):
    """
    Chat GPT with Azure Open AI
    Input: prompt (text)
    Output: results (string)
    """
    for _ in range(max_retries):
        try:
            response = openai.ChatCompletion.create(
                engine="gpt-35-turbo",  # Should be deployed in the AOAI studio
                messages=[
                    {
                        "role": "system",
                        "content": "You are an AI assistant that helps people to find \
                        information about movies.",
                    },
                    {"role": "user", "content": prompt},
                ],
                temperature=0.9,
                max_tokens=800,
                top_p=1,
                frequency_penalty=0,
                presence_penalty=0,
                stop=None,
            )

            resp = response["choices"][0]["message"]["content"]

            print("\033[1;31;34mPrompt:", prompt)
            print("\n\033[1;31;32mResponse:", resp)
            print("\033[1;31;35m")
            print("Powered by Azure AI")
            # Local time
            local_tz = pytz.timezone(
                requests.get("https://ipinfo.io").json()["timezone"]
            )
            print(datetime.now(local_tz).strftime("%d-%b-%Y %H:%M:%S"))

            return resp

        except Exception as e:
            print("Error:", str(e))
            print("Retrying...")
            time.sleep(retry_delay)

    print("Maximum retries exceeded. Unable to get a response.")

    return None

# %%
def get_movie_poster(imdb_id):
    """
    Display movie poster from its IMDB id
    Input: imdb id (string)
    Output: display image file and save as an image file
    """
    poster = mp.get_poster(id=imdb_id)
    response = requests.get(poster)

    if response.status_code == 200:
        img = Image.open(BytesIO(response.content))
        display(img)
        # Save as a local file
        os.makedirs("movieposter", exist_ok=True)
        posterfile = os.path.join("movieposter", "movie_" + str(imdb_id) + ".jpg")
        img.save(posterfile)
    else:
        print("Failed to fetch the movie image.")

# %%
def get_trailer(movietitle):
    """
    Get youtube video trailer
    Input: movie title (string)
    Output: Display the trailer video
    """
    # Search video on youtube
    videosSearch = VideosSearch(movietitle, limit=1)
    video_results = videosSearch.result().get("result")

    if video_results:
        print("\033[1;31;34m")
        video_id = video_results[0].get("id")
        video_url = f"https://www.youtube.com/watch?v={video_id}"
        print("\033[1;31;34m", video_url)
        vid = IFrame(
            src=f"https://www.youtube.com/embed/{video_id}", width="560", height="315"
        )
        display(vid)

        # Get the first 20 Youtube video comments
        print("YouTube video comments for", movietitle, ":")
        comments = Comments.get(video_id)
        print("\033[1;31;32m")

        for idx, comment in enumerate(comments.get("result")):
            print(f"Comment {idx+1:02}: {comment.get('content')}")
        print("\033[0m")
    else:
        print("No video found on YouTube.")

# %%
def get_all_movies_trailers(movies_list):
    """
    Get movie trailers from a list of movies
    Input: movies list (string)
    Output: Display the trailer video for each element of the list
    """
    for movie in movies_list:
        print(movie)
        try:
            get_trailer(movie)
        except:
            print("Error")
        print()

# %%
def acs_movies_with_posters(title):
    """
    Cross Field Search
    Input: title (string)
    Ouput: results (string)
    """
    search_client = SearchClient(
        acs_endpoint, index_name, credential=AzureKeyCredential(acs_key)
    )

    vector = Vector(value=azure_openai_text_embeddings(title), k=1, fields="embed_title")

    results = search_client.search(
        search_text=None,
        vectors=[vector],
        select=[
            "imdb_id",
            "title",
            "cast",
            "director",
            "description",
            "genres",
            "year",
        ],
        top=1,
    )

    for result in results:
        if result["@search.score"] >= 0.9:
            print("\033[1;31;34m")
            print(f"Movie title: {result['title']}")
            print(f"Movie ID: {result['imdb_id']}")
            # Get movie poster
            get_movie_poster(result["imdb_id"])
            print("\033[1;31;32m")
            print(f"Description: {result['description']}")
            print("\033[0m")
            print(f"Cast: {result['cast']}")
            print(f"Director: {result['director']}")
            print(f"Genres: {result['genres']}")
            print(f"Year: {result['year']}")
            print("\033[1;31;35m")
            print(f"Score = {result['@search.score']}")
        
        else:
            print("\033[1;31;91m")
            print(
                "Note: The movie",
                title,
                "is not available in the Azure Cognitive search index",
            )
            print("\033[0m")

# %%
def acs_movies_results(movies_list):
    """
    Find movies using Azure Cognitive Search from a list of movies
    Input: movies list (list)
    Output: results
    """
    for movie in movies_list:
        acs_movies_with_posters(movie)

# %% [markdown]
# # 4. Recommandation system

# %%
genres_list = [
    "Action",
    "Adventure",
    "Fantasy",
    "Science Fiction",
    "Crime",
    "Thriller",
    "Animation",
    "Family",
    "Western",
    "Romance",
    "Horror",
    "Mystery",
    "History",
    "War",
    "Drama",
    "Comedy",
    "Music",
]

len(genres_list)
# Out:
# 17

# %%
actors_list = [
    "Robert De Niro",
    "Al Pacino",
    "Jack Nicholson",
    "Dustin Hoffman",
    "Clint Eastwood",
    "Harrison Ford",
    "Tom Hanks",
    "Denzel Washington",
    "Morgan Freeman",
    "Mel Gibson",
    "Arnold Schwarzenegger",
    "Bruce Willis",
    "Robin Williams",
    "Kevin Costner",
    "Sean Connery",
    "Johnny Depp",
    "Samuel L. Jackson",
    "Jeff Goldblum",
    "Eddie Murphy",
    "Kurt Russell",
    "Michael Douglas",
    "Bill Murray",
    "John Travolta",
    "Richard Gere",
    "Nicolas Cage",
    "Tom Cruise",
    "Keanu Reeves",
    "Kevin Bacon",
    "Gene Hackman",
    "Danny DeVito",
    "Val Kilmer",
    "John Cusack",
    "Tim Robbins",
    "Steve Martin",
    "Patrick Swayze",
    "Tom Selleck",
    "Wesley Snipes",
    "Edward Norton",
    "Alec Baldwin",
    "Jim Carrey",
    "Will Smith",
    "Brad Pitt",
    "George Clooney",
    "Sean Penn",
    "Robert Redford",
    "Richard Dreyfuss",
    "Mark Wahlberg",
    "Johnny Depp",
    "Billy Crystal",
    "Harvey Keitel",
]

len(actors_list)
# Out:
# 50

# %%
# %%javascript
# IPython.OutputArea.auto_scroll_threshold = 9999

# %% [markdown]
# ## 1. Based on some preferences
# ### Test 1

# %%
mytopgenres = ", ".join([genres_list[0], genres_list[3], genres_list[4]])
mytopgenres
# Out:
# 'Action, Science Fiction, Crime'

# %%
mytopactors = ", ".join(
    [actors_list[2], actors_list[3], actors_list[4], actors_list[10], actors_list[20]]
)
mytopactors
# Out:
# 'Jack Nicholson, Dustin Hoffman, Clint Eastwood, Arnold Schwarzenegger, Michael Douglas'

# %%
prompt = f"I want to see a movie. Can you recommend me 10 movies? \
My favorite genres are: {mytopgenres} and my favorite actors are: {mytopactors}.\
 I want you to save only the movie title in a numbered list with the release year."

answer = azure_chatgpt_movies(prompt)
# Out:
# Prompt: I want to see a movie. Can you recommend me 10 movies? My favorite genres are: Action, Science Fiction, Crime and my favorite actors are: Jack Nicholson, Dustin Hoffman, Clint Eastwood, Arnold Schwarzenegger, Michael Douglas. I want you to save only the movie title in a numbered list with the release year.
#
# Response: Sure! Based on your preferred genres and actors, here are 10 movie recommendations:
#
# 1. The Terminator (1984)
# 2. Blade Runner (1982)
# 3. The Godfather (1972)
# 4. Die Hard (1988)
# 5. Lethal Weapon (1987)
# 6. The Dark Knight (2008)
# 7. Heat (1995)
# 8. Speed (1994)
# 9. The Fugitive (1993)
# 10. The Departed (2006)
#
# I hope you find this list helpful!
#
# Powered by Azure AI
# 04-Sep-2023 13:10:56

# %%
movies_list = get_list(answer)
# Out:
# Movie 1: The Terminator (1984).
# Movie 2: Blade Runner (1982).
# Movie 3: The Godfather (1972).
# Movie 4: Die Hard (1988).
# Movie 5: Lethal Weapon (1987).
# Movie 6: The Dark Knight (2008).
# Movie 7: Heat (1995).
# Movie 8: Speed (1994).
# Movie 9: The Fugitive (1993).
# Movie 10: The Departed (2006).

# %%
acs_movies_with_posters(movies_list)
# Out:
# Movie title: The Terminator
# Movie ID: tt0088247
# <PIL.JpegImagePlugin.JpegImageFile image mode=RGB size=380x562>
# Description: In the post-apocalyptic future reigning tyrannical supercomputers teleport a cyborg assassin known as the "Terminator" back to 1984 to kill Sarah Connor whose unborn son is destined to lead insurgents against 21st century mechanical hegemony. Meanwhile the human-resistance movement dispatches a lone warrior to safeguard Sarah. Can he stop the virtually indestructible killing machine?
#
# Cast: Arnold Schwarzenegger Michael Biehn Linda Hamilton Paul Winfield Lance Henriksen
# Director: James Cameron
# Genres: Action Thriller Science Fiction
# Year: 1984
#
# Score = 0.95015645

# %%
get_all_movies_trailers(movies_list)
# Out:
# The Terminator (1984)
#
#  https://www.youtube.com/watch?v=k64P4l2Wmeg
#         <iframe
#             width="560"
#             height="315"
#             src="https://www.youtube.com/embed/k64P4l2Wmeg"
#             frameborder="0"
#             allowfullscreen
#
#         ></iframe>
# YouTube video comments for The Terminator (1984) :
#
# Comment 01: I remember seeing this in the theater with my friends, and we all thought it looked pretty cheesy. But we went to the movie anyway, figuring it might be at least dumb fun. Then the movie totally blew us away! We knew right away that this movie was going to go down in history.
# Comment 02: One of the few movies that actually deserves its 100% on rotten tomatoes. This movie is a masterpiece. A true 80s scifi/horror... I couldn't imagine how exciting it would have been to see in 1984 opening night!
# Comment 03: This film is a masterpiece.
# Comment 04: I can tell you I was there in the cinema when it was released and it blew me away. I declared it there and then the single greatest action film and sf of all time. It literally was a perfect film. Everything that I wanted to happen, happened. Flawless in every way and a masterpiece. I couldn't get over the movie. I've never seen so many people transfixed at the cinema. Jaws did the same so did Die Hard and Misery. There are more of course but these are there ones that immediatlely come to mind
# Comment 05: This is a movie that, for me, is solidly rooted in the 80s and yet feels timeless. One of my favorites growing up.
# Comment 06: "The Terminator"(1984) is a unique masterpiece! This is the best action sci-fi movie of all time for sure!
# Comment 07: Initially I dismissed this movie as a B film, but eventually the nuances of the narrative and the effort made the filmmakers, the acting and the writing won me over. One of the best films of the 80’s, no doubt.
# Comment 08: I've seen the first Terminator innumerable times and this trailer still NEVER fails to get me hyped!
# Comment 09: There's something so special about this movie. Like I watched last night and honestly I could watch it again right now it's just beautifully made to almost perfection. T2 is amazing too don't get me wrong but for me the original terminator is one of the best movies ever made. Has to be in the top 15 films of all time somewhere for sure
# Comment 10: And to think this whole idea started because James Cameron had a fever dream of a machine crawling out of a fire trying to kill him with a knife it's amazing how something small like that can make such a masterpiece
# Comment 16: WHAT A FUCKED UP ENDING
# Comment 17: 11 years ago "The Departed" was released. What a great movie,great story,LEGENDARY actors.
# Comment 18: This and pulp fiction are my favourite movies of all time! This movie inspired me to get into screenwriting and directing. My dream is to one day direct a movie half as good as this masterpiece!
# Comment 19: Leonardo DiCaprio did a fantastic job playing this role but in my opinion he got a little over performed by Jack Nicholson who was just OUTSTANDING in this movie! The most well-played movie villian EVER!
# Comment 20: The first time I ever went to the US was in 2006 and I was lucky enough to be in Boston when this came out which is why it’s my favourite film, as well as being utterly brilliant, irrespective of it being a remake. Also Boston, what a place, been back 3 times now and still love it!

# %% [markdown]
# ## Test 2

# %%
mytopgenres = ", ".join([genres_list[8]])
print(mytopgenres)

mytopactors = ", ".join(
    [actors_list[30], actors_list[40], actors_list[45], actors_list[47]]
)
print(mytopactors)
# Out:
# Western
# Val Kilmer, Will Smith, Richard Dreyfuss, Johnny Depp

# %%
prompt = f"I want to see a movie. Show me a list of 3 movies. \
My favorite genres are: {mytopgenres} and my favorite actors are: {mytopactors}.\
 I want you to save only the movie title in a numbered list with the release year."

answer = azure_chatgpt_movies(prompt)
# Out:
# Prompt: I want to see a movie. Show me a list of 3 movies. My favorite genres are: Western and my favorite actors are: Val Kilmer, Will Smith, Richard Dreyfuss, Johnny Depp. I want you to save only the movie title in a numbered list with the release year.
#
# Response: Sure, here are 3 movies that match your preferences:
#
# 1. Tombstone (1993)
# 2. Wild Wild West (1999)
# 3. The Lone Ranger (2013)
#
# Powered by Azure AI
# 04-Sep-2023 13:12:01

# %%
movies_list = get_list(answer)
# Out:
# Movie 1: Tombstone (1993).
# Movie 2: Wild Wild West (1999).
# Movie 3: The Lone Ranger (2013).

# %%
acs_movies_with_posters(movies_list)
# Out:
# Movie title: Tombstone
# Movie ID: tt0108358
# <PIL.JpegImagePlugin.JpegImageFile image mode=RGB size=380x562>
# Description: Legendary marshal Wyatt Earp now a weary gunfighter joins his brothers Morgan and Virgil to pursue their collective fortune in the thriving mining town of Tombstone. But Earp is forced to don a badge again and get help from his notorious pal Doc Holliday when a gang of renegade brigands and rustlers begins terrorizing the town.
#
# Cast: Kurt Russell Val Kilmer Sam Elliott Bill Paxton Stephen Lang
# Director: George P. Cosmatos
# Genres: Action Adventure Drama History Western
# Year: 1993
#
# Score = 0.94058454

# %%
get_all_movies_trailers(movies_list)
# Out:
# Tombstone (1993)
#
#  https://www.youtube.com/watch?v=MICPyrnGYwg
#         <iframe
#             width="560"
#             height="315"
#             src="https://www.youtube.com/embed/MICPyrnGYwg"
#             frameborder="0"
#             allowfullscreen
#
#         ></iframe>
# YouTube video comments for Tombstone (1993) :
#
# Comment 01: A room of people that thinks he's just joking around but Johnny and Doc knew. Doc mimicked his entire routine by only seeing it once, a routine Johnny probably practiced many times to get down. What a scene, what a movie
# Comment 02: “Not Me, I’m in my prime” greatest movie line ever. Val killed it
# Comment 03: Watching Val play that role never gets old. He really sold his sickness and his final seen actually brought a tear to my eye.
# Comment 04: “Look darlin, it’s Johnny Ringoo” kills me everytime
# Comment 05: I know everyone creams over Val Kilmer, and rightly so, but the
# Comment 06: Val Kilmer is grossly underrated, The guy could do it all. Comedy, action and drama. He should have had a lot more under his belt.
# Comment 12: "oh I've got a telegram for you, its from his mother she wants him to come home and stop all the foolishness." I loved this line.
# Comment 13: i felt like watching The Matrix but decided not to. Instead I am watching this masterpiece.
# Comment 14: This movie was ahead of its time. Great movie!
# Comment 15: This was my favorite movie back when I was a kid it's too bad movie directors didn't make a wild wild west 2 and 3 all those years
# Comment 16: Westworld Season 2 looks awesome!
# Comment 17: this movie is so good,it has everything
# Comment 18: If you were alive in 1999 you couldn't ignore the saturation marketing this film got. You were pretty much guaranteed to see the trailer multiple times an hour watching TV.
# Comment 19: Everything about this movie just screams late-90s/early-2000s.
# Comment 20: Ok, imagine this, but cyberpunk, and Will Smith is a cowboy rasta in deep space. THAT needs to be a movie.
#
#
# The Lone Ranger (2013)
#
#  https://www.youtube.com/watch?v=t7fNSzLtRjk
#         <iframe
#             width="560"
#             height="315"
#             src="https://www.youtube.com/embed/t7fNSzLtRjk"
#             frameborder="0"
#             allowfullscreen
#
#         ></iframe>
# YouTube video comments for The Lone Ranger (2013) :
#
# Comment 01: You can put Johnny Depp in any movie in the world and he can make it 10 times better and funnier
# Comment 02: I don’t care what critics and most people say, I love this movie 10 / 10
# Comment 03: “Makes no difference. We are already ghosts”
# Comment 04: My dad and grandfather both watched westerns and classic horror movies with me growing up. This one, the 2013 version is one in a collection of many great movies I have saved to show my kids and grandkids one day..I do not understand how this movie was poorly received. It was amazing.
# Comment 05: I really want to see this movie. Every clip with Johnny Depp seems funny as hell.
# Comment 06: I always loved Johnny Depp's comedic performance
# Comment 07: I love the movie shattering the Western heroics (the old shows about Lone Ranger), with adding Western realistic brutality and comedy. (The clashes between US army and Native Americans back then are pretty much messed up)
# Comment 08: I love to see a small community of people who actually enjoyed this movie.
# Comment 09: RIP and long live Saginaw Grant (July 20, 1936 – July 27, 2021), aged 85
# Comment 10: This was such a good movie. I remember having so much fun seeing it in theaters.
# Comment 11: Saw this movie at the theater with my girlfriend. Loved it. Every scene with Tonto was hilarious. Wrong brother died :p
# Comment 12: My childhood was formed around the movie
# Comment 13: Disney plus really needs to add this already
# Comment 14: People accuse Johnny Depp of being a predator, yet this movie had an actual predator (Armie Hammer) who is also a cannibal.
# Comment 15: "This day were a good day to die"....
# Comment 16: May I just say that the black stripes of paint on Johnny Depp's face make him look funny even without saying a word
# Comment 17: im a asian and i love this movie, full of humor and no weird jokes
# Comment 18: I don't know why I felt this film is universal then a disney film
# Comment 19: There is only 1 scene but it is still a great scene
# Comment 20: Johnny is the best & handsome actor ever

# %% [markdown]
# ## 2. Based on some history
# ### Test 1

# %%
myfavoritemovies = "Jaws, 47 Meters Down, The Shallows"

# %%
prompt = f"My favorites movies are: {myfavoritemovies}.\
 Can you suggest me some 3 similar movies made before 2015? \
 I want you to save only the movie title in a numbered list with the release year."

answer = azure_chatgpt_movies(prompt)
# Out:
# Prompt: My favorites movies are: Jaws, 47 Meters Down, The Shallows. Can you suggest me some 3 similar movies made before 2015?  I want you to save only the movie title in a numbered list with the release year.
#
# Response: Sure, here are three similar movies that were made before 2015:
#
# 1. Open Water (2003)
# 2. Deep Blue Sea (1999)
# 3. The Reef (2010)
#
# Powered by Azure AI
# 04-Sep-2023 13:12:09

# %%
movies_list = get_list(answer)
# Out:
# Movie 1: Open Water (2003).
# Movie 2: Deep Blue Sea (1999).
# Movie 3: The Reef (2010).

# %%
acs_movies_with_posters(movies_list)
# Out:
# Movie title: Open Water
# Movie ID: tt0374102
# <PIL.JpegImagePlugin.JpegImageFile image mode=RGB size
# Comment 09: This movie is really good I just hate the fact that you never know what happens to the fisherman who decides to stay.. I really wanted to either see him survive, find help, or get eaten :D
# Comment 10: Such a great movie, perfect pacing and suspense. I just absolutely loved it.
# Comment 11: Wow this is seriously the best shark movie since Jaws. I was frigging terrified. People who got more than what they bargained for were actually leaving the cinema 3/4 of the way through. The shark stalks and toys with the characters until they're psychological meses. I was a scrunched up ball of tension for most of the movie. I won't be going in the water any time soon.
# Comment 12: the most scary movie ever!!! Focused on the desperation and panic reaction of its characters with whom the spectator is identified, the film makes you experience through them a horrifying nightmare...Sheer terror, from the begining to the end, dumb or active, yet, in any case, almost unbearable! Another great australian film! Awesome! realistic, true and frightening much much more than any american super production of this genre has ever achieved in the past. A must for great excitement fans!!!
# Comment 13: Just watched it, and I agree-this was a good film. And suprisingly, it keeps your attention.
# Comment 14: I thought the movie was excellent and well put together.  There is even a heroic aspect to it.  There is more to this movie than what first meets the eye.  It is worth watching.
# Comment 15: This is a really good movie to me. I watched it twice and loved it both times. It looks like nothing but it is really something. I love australian Horror.
# Comment 16: Great movie, well shot and unlike all other shark movies they use real sharks to film the attack scenes.  great editing
# Comment 17: It's actually a decent film and the shark does look very real and the deaths are very real as well! :)
# Comment 18: There was some amazing acting and directing in this film.  Incredibly powerful!
# Comment 19: One of the best shark films in a long time, got tired of seeing CGI used to shit. Like who remembers shark knight ? Was just fucking terrible visually but this film scared the shit out of me at certain points just knowing it happened to some poor fuckers
# Comment 20: Just saw Midnight Movie: Killer Cut and really liked it. It had a cool premise that referenced back to classic, old horror movies like the original Texas Chainsaw Massacre, which I loved. There's also this cool movie-in-a-movie aspect that brings it back to the present really well. I'm not a big fan of too much gore, but this was the perfect amount for me. The special effects are awesome. A Must See!!

# %% [markdown]
# ### Test 2

# %%
myfavoritemovies = "Manhattan, French connection, Serpico"

# %%
prompt = f"My favorites movies are: {myfavoritemovies}.\
 Can you suggest me some 5 similar movies? \
 I want you to save only the movie title in a numbered list with the release year."

answer = azure_chatgpt_movies(prompt)
# Out:
# Prompt: My favorites movies are: Manhattan, French connection, Serpico. Can you suggest me some 5 similar movies?  I want you to save only the movie title in a numbered list with the release year.
#
# Response: Yes, I can definitely help you with that. Here are 5 similar movies to your favorites:
#
# 1. "Taxi Driver" (1976)
# 2. "Annie Hall" (1977)
# 3. "Chinatown" (1974)
# 4. "The Conversation" (1974)
# 5. "Dog Day Afternoon" (1975)
#
# Powered by Azure AI
# 04-Sep-2023 13:12:18

# %%
movies_list = get_list(answer)
# Out:
# Movie 1: "Taxi Driver" (1976).
# Movie 2: "Annie Hall" (1977).
# Movie 3: "Chinatown" (1974).
# Movie 4: "The Conversation" (1974).
# Movie 5: "Dog Day Afternoon" (1975).

# %%
acs_movies_with_posters(movies_list)
# Out:
# Movie title: Taxi Driver
# Movie ID: tt0075314
# <PIL.JpegImagePlugin.JpegImageFile image mode=RGB size=380x562>
# Description: A mentally unstable Vietnam War veteran works as a night-time taxi driver in New York City where the perceived decadence and sleaze feeds his urge for violent action attempting to save a preadolescent prostitute in the process.
#
# Cast: Robert De Niro Cybill Shepherd Harvey Keitel Jodie Foster Peter Boyle
# Director: Martin Scorsese
# Genres: Crime Drama
# Year: 1976
#
# Score = 0.9408494

# %%
get_all_movies_trailers(movies_list)
# Out:
# "Taxi Driver" (1976)
#
#  https://www.youtube.com/watch?v=T5IligQP7Fo
#         <iframe
#             width="560"
#             height="315"
#             src="https://www.youtube.com/embed
# Comment 09: Incredible - I love the Don LaFontaine-esque voiceover for the trailer. The whole concept of the trailer changed since his death!
# Comment 10: RIP Sidney Lumet (June 25, 1924 – April 9, 2011), aged 86
# Comment 11: The film is a masterpiece.
# Comment 12: This movie is so real. They made movies back then!!!!!!  Great acting, writing.
# Comment 13: This trailer is like watching the whole movie
# Comment 14: Masterpiece
# Comment 15: Not only is this one of the greatest movies i’ve ever seen, but it also introduced me to my king’s beautiful ballad that i eventually named one of my original characters by,
# Comment 16: Two legends in a film
# Comment 17: Watching Silverton Siege 2022, so came here to recollect some iconic scenes by Al Pacino. I believe Silverton Siege or any  hostage movie is inspired by this movie
# Comment 18: This movie was based on an actual bank robbery that happened across the street from my apartment.
# Comment 19: One of the best trailers of all time
# Comment 20: Great film saw this some 40 years ago. Pacino. Such a great actor never made a bad film

# %% [markdown]
# ## 3. Post Processing

# %%
acs_index_status(index_name)
# Out:
# Azure Cognitive Search Index: moviereview
#
# {
#      "@odata.context": "https://azurecogsearcheastussr.search.windows.net/$metadata#indexes/$entity",
#      "@odata.etag": "\"0x8DBAA0BED295DB4\"",
#      "name": "moviereview",
#      "defaultScoringProfile": null,
#      "fields": [
#           {
#                "name": "imdb_id",
#                "type": "Edm.String",
#                "searchable": false,
#                "filterable": true,
#                "retrievable": true,
#                "sortable": true,
#                "facetable": true,
#                "key": true,
#                "indexAnalyzer": null,
#                "searchAnalyzer": null,
#                "analyzer": null,
#                "normalizer": null,
#                "synonymMaps": []
#           },
#           {
#                "name": "title",
#                "type": "Edm.String",
#                "searchable": true,
#                "filterable": true,
#                "retrievable": true,
#                "sortable": false,
#                "facetable": false,
#                "key": false,
#                "indexAnalyzer": null,
#                "searchAnalyzer": null,
#                "analyzer": null,
#                "normalizer": null,
#                "synonymMaps": []
#           },
#           {
#                "name": "cast",
#                "type": "Edm.String",
#                "searchable": true,
#                "filterable": true,
#                "retrievable": true,
#                "sortable": false,
#                "facetable": false,
#                "key": false,
#                "indexAnalyzer": null,
#                "searchAnalyzer": null,
#                "analyzer": null,
#                "normalizer": null,
#                "synonymMaps": []
#           },
#           {
#                "name": "director",
#                "type": "Edm.String",
#                "searchable": true,
#                "filterable": true,
#                "retrievable": true,
#                "sortable": false,
#                "facetable": false,
#                "key": false,
#                "indexAnalyzer": null,
#                "searchAnalyzer": null,
#                "analyzer": null,
#                "normalizer": null,
#                "synonymMaps": []
#           },
#           {
#                "name": "description",
#                "type": "Edm.String",
#                "searchable": true,
#                "filterable": false,
#                "retrievable": true,
#                "sortable": false,
#                "facetable": false,
#                "key": false,
#                "indexAnalyzer": null,
#                "searchAnalyzer": null,
#                "analyzer": null,
#                "normalizer": null,
#                "synonymMaps": []
#           },
#           {
#                "name": "genres",
#                "type": "Edm.String",
#                "searchable": true,
#                "filterable": true,
#                "retrievable": true,
#                "sortable": false,
#                "facetable": false,
#                "key": false,
#                "indexAnalyzer": null,
#                "searchAnalyzer": null,
#                "analyzer": null,
#                "normalizer": null,
#                "synonymMaps": []
#           },
#           {
#                "name": "year",
#                "type": "Edm.String",
#                "searchable": true,
#                "filterable": true,
#                "retrievable": true,
#                "sortable": false,
#                "facetable": false,
#                "key": false,
#                "indexAnalyzer": null,
#                "searchAnalyzer": null,
#                "analyzer": null,
#                "normalizer": null,
#                "synonymMaps": []
#           },
#           {
#                "name": "embed_overview",
#                "type": "Collection(Edm.Single)",
#                "searchable": true,
#                "filterable": false,
#                "retrievable": true,
#                "sortable": false,
#                "facetable": false,
#                "key": false,
#                "indexAnalyzer": null,
#                "searchAnalyzer": null,
#                "analyzer": null,
#                "normalizer": null,
#                "synonymMaps": []
#           },
#           {
#                "name": "embed_title",
#                "type": "Collection(Edm.Single)",
#                "searchable": true,
#                "filterable": false,
#                "retrievable": true,
#                "sortable": false,
#                "facetable": false,
#                "key": false,
#                "indexAnalyzer": null,
#                "searchAnalyzer": null,
#                "analyzer": null,
#                "normalizer": null,
#                "synonymMaps": []
#           }
#      ],
#      "scoringProfiles": [],
#      "corsOptions": null,
#      "suggesters": [],
#      "analyzers": [],
#      "normalizers": [],
#      "tokenizers": [],
#      "tokenFilters": [],
#      "charFilters": [],
#      "encryptionKey": null,
#      "similarity": {
#           "@odata.type": "#Microsoft.Azure.Search.BM25Similarity",
#           "k1": null,
#           "b": null
#      },
#      "semantic": {
#           "defaultConfiguration": null,
#           "configurations": [
#                {
#                     "name": "my-semantic-config",
#                     "prioritizedFields": {
#                          "titleField": {
#                               "fieldName": "title"
#                          },
#                          "prioritizedContentFields": [
#                               {
#                                    "fieldName": "description"
#                               }
#                          ],
#                          "prioritizedKeywordsFields": [
#                               {
#                                    "fieldName": "genres"
#                               }
#                          ]
#                     }
#                }
#           ]
#      }
# }

# %%
document_count, storage_size = acs_index_stats(index_name)
# Out:
# Azure Cognitive Search index status for: moviereview
#
# {
#   "@odata.context": "https://azurecogsearcheastussr.search.windows.net/$metadata#Microsoft.Azure.Search.V2021_04_30_Preview.IndexStatistics",
#   "documentCount": 10784,
#   "storageSize": 564466206
# }

# %% [markdown]
# ### We can delete the index if needed

# %%
# acs_delete_index(index_name)

# %% [markdown]
# > End
